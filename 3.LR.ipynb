# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import make_pipeline
sns.set(rc={'figure.figsize':(15,10)})

# %%
# Generate random data with a non-linear relationship between feature and label
np.random.seed(0)
X = np.random.rand(100, 1) * 10
y = 5 * np.log(X.ravel()) + np.random.randn(100)
data = pd.DataFrame(columns=['X','y'])
data['X']=X.ravel()
data['y']=y

# %%
sns.relplot(data=data, x="X", y="y")

# %%
# Linear regression without logarithmic transformation
linear_reg = LinearRegression()
linear_reg.fit(X, y)
linear_reg_pred = linear_reg.predict(X)

# %%
plt.scatter(X, y, color='blue', label='Data')
plt.plot(X, linear_reg_pred, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
X_log = np.log1p(X)
log_transformer.fit(X_log, y)
log_transform_pred = log_transformer.predict(X_log)

# %%
sorted_idx = np.argsort(X.ravel())
X_sorted = X[sorted_idx]
X_log_sorted = np.log1p(X_sorted)
log_transform_pred = log_transformer.predict(X_log_sorted)

# %%
plt.scatter(X, y, color='blue', label='Data')
plt.plot(X_sorted, log_transform_pred, color='green', linewidth=2, label='Logarithmic Transformation')
plt.xlabel('X_log')
plt.ylabel('y')
plt.legend()
plt.show()
